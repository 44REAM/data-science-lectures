# %% [markdown]
# <a href="https://colab.research.google.com/github/44REAM/RA-Medphys/blob/main/Class_2_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz 2
#
# ให้ segmentation รูปภาพของเราโดยการ thresholding ในทางปฏิบัติ เราสามารถทำการเลือกส่วนที่เป็น soft tissue หรือ bone ใน CT image ได้โดยการเลือกเฉพาะส่วนที่ HU ของภาพตรงกับ criteria ที่เรากำหนด เช่น เราอาจจะเลือกส่วนที่เป็น bone จากส่วนที่ HU>200
#
# **Question:**
# 1.  จากข้อมูลที่อยู่ในตัวแปร img ด้านล่าง ให้ทำการ thresholding เลือกส่วนที่ intensity ของ img มากกว่า 150 แต่น้อยกว่า 200
# 2.  ให้สร้างรูปภาพอีกอันขึ้นมาให้มีขนาดเท่ากันกับ array ที่อยู่ในตัวแปร img ของเรา ซึ่งให้ intensity ข้างในรูปภาพใหม่ที่สร้างขึ้นมาเป็น 0 ทั้งหมด แต่ให้เฉพาะส่วนที่ intensity ของ img มากกว่า 150 แต่น้อยกว่า 200 มี intensity เท่ากับ 1
#
# Note: ในรูป CT จริงๆแล้ว intensity ในรูปควรจะเป็นค่า HU แต่เนื่องจากรูปนี้เป็นตัวอย่าง ค่า intensity ที่อยู่ข้างในจึงไม่ใช่ HU

# %%
# โหลดข้อมูล
# !wget "https://ctisus.com/resources/library/teaching-files/chest/375281.jpg"

import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# --2023-07-04 16:20:03--  https://ctisus.com/resources/library/teaching-files/chest/375281.jpg
# Resolving ctisus.com (ctisus.com)... 104.21.234.150, 104.21.234.151, 2606:4700:3038::6815:ea96, ...
# Connecting to ctisus.com (ctisus.com)|104.21.234.150|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44204 (43K) [image/jpeg]
# Saving to: ‘375281.jpg.1’
#
# 375281.jpg.1        100%[===================>]  43.17K  --.-KB/s    in 0.004s
#
# 2023-07-04 16:20:03 (9.69 MB/s) - ‘375281.jpg.1’ saved [44204/44204]

# %%
# รัน block ข้างบนก่อนครับ
# ข้อมูลของเรา
img = cv2.imread('375281.jpg')
img = img[:,:,0]

# ข้อมูลของเราจะอยู่ใน array ที่ชื่อว่า img
# ลอง print shape ของ array ดู
print(f"image shape = {img.shape}")

# ลอง print type ของ array ดู
print(f"image shape = {type(img)}")

# ลอง print intensity ที่มากที่สุดใน image
print(f"image max intensity = {img.max()}")

# ลอง print intensity ที่น้อยที่สุดใน image
print(f"image min intensity = {img.min()}")

# ลอง show image
plt.imshow(img, cmap = 'gray')
# Out:
# image shape = (758, 948)
# image shape = <class 'numpy.ndarray'>
# image max intensity = 255
# image max intensity = 0

# %%
# เริ่มเขียนตรงนี้ครับ
# Hint: เราอาจจะอยากสร้าง array อีกอันที่ขนาดเท่ากับ ตัวแปร img ของเรา ลองดู function zeros ที่อยู่ใน package numpy
# Hint: หา location ที่ตรงกับ condition ในโจทย์ แล้ว assign value 1
# ข้อนี้จะมีบางส่วนที่ไม่ได้สอนในห้อง อาจจะลอง google เพิ่มนะครับ (code ที่เขียนอาจจะมีที่ไม่ได้สอนในห้อง 2 บรรทัด)

# สร้าง array ใหม่ชื่อว่า
new_image_array = #

# %%
# หลังจากได้ผลแล้วอาจจะลองรัน block นี้ดูว่าผลที่ได้ออกมาเป็นแบบไหน
# imshow เป็นการแสดงผลรูปภาพ
plt.imshow(new_image_array)
